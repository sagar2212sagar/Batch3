# %%
# %sql
create catalog if not exists resume_batch3;

# %%
# %sql
create schema if not exists resume_batch3.staging;

# %%
# %sql
create schema if not exists resume_batch3.bronze;

# %%
list_schema=['bronze','gold','silver','staging']
for schema in list_schema:
  spark.sql(f"CREATE SCHEMA IF NOT EXISTS resume_batch3.{schema}")

# %%
# %sql
create volume if not exists resume_batch3.staging.source_files
